# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/KOSA-GPT_Python-2023/blob/main/gmarket-scrapy-error.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install simplified_scrapy

# %%
from simplified_scrapy import SimplifiedDoc, utils

def get_item_names(url):
    html = utils.getHtml(url)
    doc = SimplifiedDoc(html)
    items = doc.getElements('a', attr='class', value='itemname')
    item_names = [item.text for item in items]
    return item_names

url = 'https://www.gmarket.co.kr/n/best'
item_names = get_item_names(url)

for name in item_names:
    print(name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-67cfc29c4484> in <cell line: 11>()
#       9
#      10 url = 'https://www.gmarket.co.kr/n/best'
# ---> 11 item_names = get_item_names(url)
#      12
#      13 for name in item_names:
#
# <ipython-input-11-67cfc29c4484> in get_item_names(url)
#       2
#       3 def get_item_names(url):
# ----> 4     html = utils.getHtml(url)
#       5     doc = SimplifiedDoc(html)
#       6     items = doc.getElements('a', attr='class', value='itemname')
#
# AttributeError: module 'simplified_scrapy.core.utils' has no attribute 'getHtml'

# %%
from simplified_scrapy import SimplifiedDoc
import requests

def get_item_names(url):
    response = requests.get(url)
    doc = SimplifiedDoc(response.text)
    items = doc.getElements('a', attr='class', value='itemname')
    item_names = [item.text for item in items]
    return item_names

url = 'https://www.gmarket.co.kr/n/best'
item_names = get_item_names(url)

for name in item_names:
    print(name)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.gmarket.co.kr:443
# 2023-07-06 10:59:17 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): www.gmarket.co.kr:443
# DEBUG:urllib3.connectionpool:https://www.gmarket.co.kr:443 "GET /n/best HTTP/1.1" 200 None
# 2023-07-06 10:59:18 [urllib3.connectionpool] DEBUG: https://www.gmarket.co.kr:443 "GET /n/best HTTP/1.1" 200 None
# 참닭 춘천형 닭갈비 700g x 4팩 총 2.8kg (쿠폰 17600원)
# [롯데칠성]펩시콜라 제로 210ml x 60캔 (30캔 2박스)
# [피앤지](1+1) 케스케이드 플래티넘 액션팩 식기세척기 세제 (92개입)/ 2팩세트/ 총 194개입/ 미국제조/ 무료배송
# 올반 꿔바로우 500gx5팩 (쿠폰 25140원)
# [올반키친]올반 찰핫도그15봉+크런치핫도그15봉(신세계푸드 중복쿠폰 할인)
# [Gfresh]고등어 160-180g x 10팩/왕특대/HACCP위생환경생산/국내산
# [네파](신세계경기점)네파 NEPA DS-BG 디에스슬링백 7JG7550
# 의성 군위 햇 대석 자두 중과 2kg(36-44개) 50g내외
# [구글플레이]기프트코드 10만원 / 구글 기프트카드
# [랩시리즈](신세계강남점)[7] [정품증정] 데일리 레스큐 워터로션 200ml (+ 정품 올인원 증정)
# 복숭아 경북 노지 아삭이 복숭아 1.5kg(5-7과)/대과
# [빙그레]아이스크림 슈퍼콘/요맘때콘 20+20개 골라담기
# [동원에프앤비]DHA 참치 150g 원터치 10개
# [메가박스](유니버스클럽 전용) 메가박스 일반예매권 2D-주중/주말
# ...
